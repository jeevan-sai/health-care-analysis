# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
df=pd.read_csv("C:\\Users\\HP 745 G6\\Downloads\\healthcare_dataset (1).csv")

# %%
df
# Out:
#                       Name  Age  Gender Blood Type Medical Condition  \
# 0          Tiffany Ramirez   81  Female         O-          Diabetes
# 1              Ruben Burns   35    Male         O+            Asthma
# 2                Chad Byrd   61    Male         B-           Obesity
# 3        Antonio Frederick   49    Male         B-            Asthma
# 4      Mrs. Brandy Flowers   51    Male         O-         Arthritis
# ...                    ...  ...     ...        ...               ...
# 9995            James Hood   83    Male         A+           Obesity
# 9996       Stephanie Evans   47  Female        AB+         Arthritis
# 9997  Christopher Martinez   54    Male         B-         Arthritis
# 9998           Amanda Duke   84    Male         A+         Arthritis
# 9999             Eric King   20    Male         B-         Arthritis
#
#      Date of Admission             Doctor                   Hospital  \
# ...

# %% [markdown]
# ### data Cleaning

# %%
df.head(5)
# Out:
#                   Name  Age  Gender Blood Type Medical Condition  \
# 0      Tiffany Ramirez   81  Female         O-          Diabetes
# 1          Ruben Burns   35    Male         O+            Asthma
# 2            Chad Byrd   61    Male         B-           Obesity
# 3    Antonio Frederick   49    Male         B-            Asthma
# 4  Mrs. Brandy Flowers   51    Male         O-         Arthritis
#
#   Date of Admission          Doctor                   Hospital  \
# 0        2022-11-17  Patrick Parker           Wallace-Hamilton
# 1        2023-06-01   Diane Jackson  Burke, Griffin and Cooper
# 2        2019-01-09      Paul Baker                 Walton LLC
# 3        2020-05-02  Brian Chandler                 Garcia Ltd
# 4        2021-07-09  Dustin Griffin    Jones, Brown and Murray
#
#   Insurance Provider  Billing Amount  Room Number Admission Type  \
# 0           Medicare    37490.983364          146       Elective
# ...

# %%
df.isna().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                10000 non-null  object
#  1   Age                 10000 non-null  int64
#  2   Gender              10000 non-null  object
#  3   Blood Type          10000 non-null  object
#  4   Medical Condition   10000 non-null  object
#  5   Date of Admission   10000 non-null  object
#  6   Doctor              10000 non-null  object
#  7   Hospital            10000 non-null  object
#  8   Insurance Provider  10000 non-null  object
#  9   Billing Amount      10000 non-null  float64
#  10  Room Number         10000 non-null  int64
#  11  Admission Type      10000 non-null  object
#  12  Discharge Date      10000 non-null  object
#  13  Medication          10000 non-null  object
#  14  Test Results        10000 non-null  object
# ...

# %%
df.describe()
# Out:
#                 Age  Billing Amount   Room Number
# count  10000.000000    10000.000000  10000.000000
# mean      51.452200    25516.806778    300.082000
# std       19.588974    14067.292709    115.806027
# min       18.000000     1000.180837    101.000000
# 25%       35.000000    13506.523967    199.000000
# 50%       52.000000    25258.112566    299.000000
# 75%       68.000000    37733.913727    400.000000
# max       85.000000    49995.902283    500.000000

# %%
sns.boxplot(df)
plt.show()

# %%
df
# Out:
#                       Name  Age  Gender Blood Type Medical Condition  \
# 0          Tiffany Ramirez   81  Female         O-          Diabetes
# 1              Ruben Burns   35    Male         O+            Asthma
# 2                Chad Byrd   61    Male         B-           Obesity
# 3        Antonio Frederick   49    Male         B-            Asthma
# 4      Mrs. Brandy Flowers   51    Male         O-         Arthritis
# ...                    ...  ...     ...        ...               ...
# 9995            James Hood   83    Male         A+           Obesity
# 9996       Stephanie Evans   47  Female        AB+         Arthritis
# 9997  Christopher Martinez   54    Male         B-         Arthritis
# 9998           Amanda Duke   84    Male         A+         Arthritis
# 9999             Eric King   20    Male         B-         Arthritis
#
#      Date of Admission             Doctor                   Hospital  \
# ...

# %%
df["Gender"].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df["Gender"].value_counts()
# Out:
# Gender
# Female    5075
# Male      4925
# Name: count, dtype: int64

# %%
df["Admission Type"].unique()
# Out:
# array(['Elective', 'Emergency', 'Urgent'], dtype=object)

# %%
df["Admission Type"].value_counts()
# Out:
# Admission Type
# Urgent       3391
# Emergency    3367
# Elective     3242
# Name: count, dtype: int64

# %%
df["Insurance Provider"].unique()
# Out:
# array(['Medicare', 'UnitedHealthcare', 'Aetna', 'Cigna', 'Blue Cross'],
#       dtype=object)

# %%
from sklearn.preprocessing import OneHotEncoder,LabelEncoder
OE=OneHotEncoder()

# %%
OE.fit(df[["Gender"]])
# Out:
# OneHotEncoder()

# %%
df["Gender"]=OE.transform(df[["Gender"]]).toarray()

# %%
df
# Out:
#                       Name  Age  Gender Blood Type Medical Condition  \
# 0          Tiffany Ramirez   81     1.0         O-          Diabetes
# 1              Ruben Burns   35     0.0         O+            Asthma
# 2                Chad Byrd   61     0.0         B-           Obesity
# 3        Antonio Frederick   49     0.0         B-            Asthma
# 4      Mrs. Brandy Flowers   51     0.0         O-         Arthritis
# ...                    ...  ...     ...        ...               ...
# 9995            James Hood   83     0.0         A+           Obesity
# 9996       Stephanie Evans   47     1.0        AB+         Arthritis
# 9997  Christopher Martinez   54     0.0         B-         Arthritis
# 9998           Amanda Duke   84     0.0         A+         Arthritis
# 9999             Eric King   20     0.0         B-         Arthritis
#
#      Date of Admission             Doctor                   Hospital  \
# ...

# %%
df["Gender"].value_counts()
# Out:
# Gender
# 1.0    5075
# 0.0    4925
# Name: count, dtype: int64

# %%
df["Admission Type"]=df["Admission Type"].replace({'Elective':0, 'Emergency':1, 'Urgent':2})

# %%
df["Admission Type"].unique()
# Out:
# array([0, 1, 2], dtype=int64)

# %%
df
# Out:
#                       Name  Age  Gender Blood Type Medical Condition  \
# 0          Tiffany Ramirez   81     1.0         O-          Diabetes
# 1              Ruben Burns   35     0.0         O+            Asthma
# 2                Chad Byrd   61     0.0         B-           Obesity
# 3        Antonio Frederick   49     0.0         B-            Asthma
# 4      Mrs. Brandy Flowers   51     0.0         O-         Arthritis
# ...                    ...  ...     ...        ...               ...
# 9995            James Hood   83     0.0         A+           Obesity
# 9996       Stephanie Evans   47     1.0        AB+         Arthritis
# 9997  Christopher Martinez   54     0.0         B-         Arthritis
# 9998           Amanda Duke   84     0.0         A+         Arthritis
# 9999             Eric King   20     0.0         B-         Arthritis
#
#      Date of Admission             Doctor                   Hospital  \
# ...

# %%
df["Insurance Provider"]=df["Insurance Provider"].replace({'Medicare':0, 'UnitedHealthcare':1, 'Aetna':2, 'Cigna':3, 'Blue Cross':4})

# %%
df
# Out:
#                       Name  Age  Gender Blood Type Medical Condition  \
# 0          Tiffany Ramirez   81     1.0         O-          Diabetes
# 1              Ruben Burns   35     0.0         O+            Asthma
# 2                Chad Byrd   61     0.0         B-           Obesity
# 3        Antonio Frederick   49     0.0         B-            Asthma
# 4      Mrs. Brandy Flowers   51     0.0         O-         Arthritis
# ...                    ...  ...     ...        ...               ...
# 9995            James Hood   83     0.0         A+           Obesity
# 9996       Stephanie Evans   47     1.0        AB+         Arthritis
# 9997  Christopher Martinez   54     0.0         B-         Arthritis
# 9998           Amanda Duke   84     0.0         A+         Arthritis
# 9999             Eric King   20     0.0         B-         Arthritis
#
#      Date of Admission             Doctor                   Hospital  \
# ...

# %%
df["Medication"].unique()
# Out:
# array(['Aspirin', 'Lipitor', 'Penicillin', 'Paracetamol', 'Ibuprofen'],
#       dtype=object)

# %%
df["Date of Admission"]=pd.to_datetime(df["Date of Admission"])

# %%
df["Discharge Date"]=pd.to_datetime(df["Discharge Date"])

# %%
df["length stay"]=df["Date of Admission"].dt.day-df["Discharge Date"].dt.day

# %%
df
# Out:
#                       Name  Age  Gender Blood Type Medical Condition  \
# 0          Tiffany Ramirez   81     1.0         O-          Diabetes
# 1              Ruben Burns   35     0.0         O+            Asthma
# 2                Chad Byrd   61     0.0         B-           Obesity
# 3        Antonio Frederick   49     0.0         B-            Asthma
# 4      Mrs. Brandy Flowers   51     0.0         O-         Arthritis
# ...                    ...  ...     ...        ...               ...
# 9995            James Hood   83     0.0         A+           Obesity
# 9996       Stephanie Evans   47     1.0        AB+         Arthritis
# 9997  Christopher Martinez   54     0.0         B-         Arthritis
# 9998           Amanda Duke   84     0.0         A+         Arthritis
# 9999             Eric King   20     0.0         B-         Arthritis
#
#      Date of Admission             Doctor                   Hospital  \
# ...

# %% [markdown]
# ### EDA

# %% [markdown]
# ### Patient Demographics

# %%
df["Age"].hist(bins=20,width=0.9)
plt.show()

# %%
df["Gender"].value_counts().plot(kind="bar")
plt.show()

# %%
df["Blood Type"].value_counts().plot(kind="bar",color="g")
plt.show()

# %% [markdown]
# ### Hospital Operations:

# %%
x=df["Admission Type"].value_counts()

# %%
x.plot(kind="bar",color="r")
plt.title("Admission type")
plt.show()

# %% [markdown]
# ### health costs

# %%
billingsummary=df.groupby(["Insurance Provider","Admission Type"])["Billing Amount"].describe()

# %%
billingsummary
# Out:
#                                    count          mean           std  \
# Insurance Provider Admission Type
# 0                  0               631.0  25110.915502  14259.547693
#                    1               639.0  24292.203100  14047.026095
#                    2               655.0  25590.945592  13930.720113
# 1                  0               612.0  25654.454199  14345.867263
#                    1               691.0  24848.152459  13955.383103
#                    2               675.0  25747.953154  13671.865883
# 2                  0               659.0  26078.444532  14297.011735
#                    1               706.0  25231.925601  14290.666608
#                    2               660.0  26246.000513  13751.933644
# 3                  0               652.0  26615.752959  14012.849505
#                    1               679.0  24560.280198  14543.506289
#                    2               709.0  25825.487177  13531.800887
# ...

# %%
sns.boxplot(data=df,x="Insurance Provider",y="Billing Amount")
plt.title("billing summary")
plt.show()

# %%
df
# Out:
#                       Name  Age  Gender Blood Type Medical Condition  \
# 0          Tiffany Ramirez   81     1.0         O-          Diabetes
# 1              Ruben Burns   35     0.0         O+            Asthma
# 2                Chad Byrd   61     0.0         B-           Obesity
# 3        Antonio Frederick   49     0.0         B-            Asthma
# 4      Mrs. Brandy Flowers   51     0.0         O-         Arthritis
# ...                    ...  ...     ...        ...               ...
# 9995            James Hood   83     0.0         A+           Obesity
# 9996       Stephanie Evans   47     1.0        AB+         Arthritis
# 9997  Christopher Martinez   54     0.0         B-         Arthritis
# 9998           Amanda Duke   84     0.0         A+         Arthritis
# 9999             Eric King   20     0.0         B-         Arthritis
#
#      Date of Admission             Doctor                   Hospital  \
# ...

# %%
df["Test Results"].value_counts().plot(kind="bar",color=["r","b","y"])
plt.show()

# %%
medical_test_outcomes=df.groupby(["Medication","Test Results"]).size().unstack(fill_value=0)

# %%
medical_test_outcomes
# Out:
# Test Results  Abnormal  Inconclusive  Normal
# Medication
# Aspirin            654           634     680
# Ibuprofen          680           627     669
# Lipitor            721           685     609
# Paracetamol        685           651     626
# Penicillin         716           680     683

# %%
plt.figure(figsize=(8,6))
sns.heatmap(medical_test_outcomes,annot=True,fmt="d",cmap="coolwarm")
plt.show()

# %% [markdown]
# ##### predictive model

# %%
df
# Out:
#                       Name  Age  Gender Blood Type Medical Condition  \
# 0          Tiffany Ramirez   81     1.0         O-          Diabetes
# 1              Ruben Burns   35     0.0         O+            Asthma
# 2                Chad Byrd   61     0.0         B-           Obesity
# 3        Antonio Frederick   49     0.0         B-            Asthma
# 4      Mrs. Brandy Flowers   51     0.0         O-         Arthritis
# ...                    ...  ...     ...        ...               ...
# 9995            James Hood   83     0.0         A+           Obesity
# 9996       Stephanie Evans   47     1.0        AB+         Arthritis
# 9997  Christopher Martinez   54     0.0         B-         Arthritis
# 9998           Amanda Duke   84     0.0         A+         Arthritis
# 9999             Eric King   20     0.0         B-         Arthritis
#
#      Date of Admission             Doctor                   Hospital  \
# ...

# %%
df["Medical Condition"].unique()
# Out:
# array(['Diabetes', 'Asthma', 'Obesity', 'Arthritis', 'Hypertension',
#        'Cancer'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
L=LabelEncoder()

# %%
L.fit(df[["Medical Condition"]])
# Out:
# LabelEncoder()

# %%
df["Medical Condition"]=L.transform(df[["Medical Condition"]])

# %%
df.head(16)
# Out:
#                      Name  Age  Gender Blood Type  Medical Condition  \
# 0         Tiffany Ramirez   81     1.0         O-                  3
# 1             Ruben Burns   35     0.0         O+                  1
# 2               Chad Byrd   61     0.0         B-                  5
# 3       Antonio Frederick   49     0.0         B-                  1
# 4     Mrs. Brandy Flowers   51     0.0         O-                  0
# 5          Patrick Parker   41     0.0        AB+                  0
# 6          Charles Horton   82     0.0        AB+                  4
# 7            Patty Norman   55     1.0         O-                  0
# 8              Ryan Hayes   33     0.0         A+                  3
# 9            Sharon Perez   39     1.0         O-                  1
# 10            Amy Roberts   45     0.0         B-                  2
# 11  Mrs. Caroline Farrell   23     1.0         O-                  4
# 12     Christina Williams   85     1.0         A+                  3
# ...

# %%
df
# Out:
#                       Name  Age  Gender Blood Type  Medical Condition  \
# 0          Tiffany Ramirez   81     1.0         O-                  3
# 1              Ruben Burns   35     0.0         O+                  1
# 2                Chad Byrd   61     0.0         B-                  5
# 3        Antonio Frederick   49     0.0         B-                  1
# 4      Mrs. Brandy Flowers   51     0.0         O-                  0
# ...                    ...  ...     ...        ...                ...
# 9995            James Hood   83     0.0         A+                  5
# 9996       Stephanie Evans   47     1.0        AB+                  0
# 9997  Christopher Martinez   54     0.0         B-                  0
# 9998           Amanda Duke   84     0.0         A+                  0
# 9999             Eric King   20     0.0         B-                  0
#
#      Date of Admission             Doctor                   Hospital  \
# ...

# %%
df.to_excel("output.xlsx",index=False)

# %%
df.drop(["Date of Admission","Discharge Date"],axis=1,inplace=True)

# %%
df.drop(["Doctor","Hospital"],axis=1,inplace=True)

# %%
L.fit(df[["Medication"]])
# Out:
# LabelEncoder()

# %%
df["Medication"]=L.transform(df[["Medication"]])

# %%
L.fit(df[["Blood Type"]])
# Out:
# LabelEncoder()

# %%
df["Blood Type"]=L.transform(df[["Blood Type"]])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 10000 non-null  int64
#  1   Gender              10000 non-null  float64
#  2   Blood Type          10000 non-null  int64
#  3   Medical Condition   10000 non-null  int32
#  4   Insurance Provider  10000 non-null  int64
#  5   Billing Amount      10000 non-null  float64
#  6   Room Number         10000 non-null  int64
#  7   Admission Type      10000 non-null  int64
#  8   Medication          10000 non-null  int64
#  9   Test Results        10000 non-null  int64
#  10  length stay         10000 non-null  int32
# dtypes: float64(2), int32(2), int64(7)
# memory usage: 781.4 KB

# %%
# df.drop("Name",axis=1,inplace=True)

# %%
X=df.drop("Test Results",axis=1)

# %%
y=df["Test Results"]

# %%
X
# Out:
#       Age  Gender  Blood Type  Medical Condition  Insurance Provider  \
# 0      81     1.0           7                  3                   0
# 1      35     0.0           6                  1                   1
# 2      61     0.0           5                  5                   0
# 3      49     0.0           5                  1                   0
# 4      51     0.0           7                  0                   1
# ...   ...     ...         ...                ...                 ...
# 9995   83     0.0           0                  5                   1
# 9996   47     1.0           2                  0                   4
# 9997   54     0.0           5                  0                   4
# 9998   84     0.0           0                  0                   1
# 9999   20     0.0           5                  0                   2
#
#       Billing Amount  Room Number  Admission Type  Medication  length stay
# ...

# %%
y
# Out:
# 0       0
# 1       1
# 2       1
# 3       2
# 4       1
#        ..
# 9995    2
# 9996    1
# 9997    1
# 9998    1
# 9999    2
# Name: Test Results, Length: 10000, dtype: int64

# %%
df["Test Results"].unique()
# Out:
# array([0, 1, 2], dtype=int64)

# %%
df["Test Results"]=df["Test Results"].replace({'Inconclusive':0, 'Normal':1, 'Abnormal':2})

# %%
y=df["Test Results"]

# %%
y
# Out:
# 0       0
# 1       1
# 2       1
# 3       2
# 4       1
#        ..
# 9995    2
# 9996    1
# 9997    1
# 9998    1
# 9999    2
# Name: Test Results, Length: 10000, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
Xtrain,Xtest,ytrain,ytest=train_test_split(X,y,test_size=0.20,random_state=42,stratify=y)

# %%
Xtrain.shape,Xtest.shape,X.shape
# Out:
# ((8000, 10), (2000, 10), (10000, 10))

# %%
ytrain.shape,ytest.shape,y.shape
# Out:
# ((8000,), (2000,), (10000,))

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rmodel=RandomForestClassifier()

# %%
rmodel.fit(Xtrain,ytrain)
# Out:
# RandomForestClassifier()

# %%
rmodel.score(Xtest,ytest)
# Out:
# 0.349

# %%
ypred=rmodel.predict(Xtest)

# %%
ypred
# Out:
# array([2, 0, 0, ..., 1, 2, 2], dtype=int64)

# %%
from sklearn.ensemble import GradientBoostingClassifier
gmodel=GradientBoostingClassifier()

# %%
gmodel.fit(Xtrain,ytrain)
# Out:
# GradientBoostingClassifier()

# %%
gmodel.score(Xtest,ytest)
# Out:
# 0.3455

# %%
ypred1=gmodel.predict(Xtest)

# %%
ypred1
# Out:
# array([2, 1, 0, ..., 0, 1, 0], dtype=int64)

# %%
from sklearn.metrics import accuracy_score,f1_score,precision_score,recall_score

# %%
a=accuracy_score(ytest,ypred)
print(a)
# Out:
# 0.349

# %%
A=accuracy_score(ytest,ypred1)
print(A)
# Out:
# 0.3455

# %%
pip install tensorflow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Dense

# %% [markdown]
# sm=Sequential(
#                [Dense (64,activation="relu",input_shape=

# %%
sm=Sequential( [Dense (64,activation="relu",input_dim=Xtrain.shape[1]),
                Dense (32,activation="relu"),
                Dense (16,activation="relu"),
                Dense ( 5,activation="softmax")])

# %%
sm.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 64)                  │             704 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 5)                   │              85 │
# ...

# %%
sm.compile(optimizer="adam",loss="sparse_categorical_crossentropy",metrics=["accuracy"])

# %%
sm.fit(Xtrain,ytrain,epochs=10)
# Out:
# Epoch 1/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.3271 - loss: 187.4165
# Epoch 2/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3206 - loss: 27.2809
# Epoch 3/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3203 - loss: 30.3944
# Epoch 4/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3340 - loss: 35.1259
# Epoch 5/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3274 - loss: 31.4204
# Epoch 6/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3338 - loss: 19.8036
# Epoch 7/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3416 - loss: 21.4117
# Epoch 8/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3252 - loss: 16.5540
# Epoch 9/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3205 - loss: 15.3234
# Epoch 10/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3364 - loss: 19.2294

# %%
smpredit=sm.predict(Xtest)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
smpredit[1400]
# Out:
# array([9.2989849e-06, 3.2980740e-04, 9.9966085e-01, 0.0000000e+00,
#        0.0000000e+00], dtype=float32)
